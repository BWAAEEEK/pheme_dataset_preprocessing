# %%
import pickle
import networkx as nx
import matplotlib.pyplot as plt

# %%
with open("./graph_dict.pkl", "rb") as f:
    graph_dict: dict = pickle.load(f)

# %%
nx.draw(graph_dict["ottawashooting-all-rnr-threads"]["rumours"][0], with_labels=True)

# %%
from pprint import PrettyPrinter

# %%
PrettyPrinter().pprint(dict(graph_dict["ottawashooting-all-rnr-threads"]["rumours"][0].nodes(data=True)))
# Out:
# {524922507380670464: {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Wed Oct 22 13:57:33 +0000 2014',
#                       'entities': {'hashtags': [{'indices': [0, 7],
#                                                  'text': 'Ottawa'}],
#                                    'symbols': [],
#                                    'trends': [],
#                                    'urls': [],
#                                    'user_mentions': []},
#                       'favorite_count': 23,
#                       'favorited': False,
#                       'filter_level': 'low',
#                       'geo': None,
#                       'id': 524922507380670464,
#                       'id_str': '524922507380670464',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
# ...
